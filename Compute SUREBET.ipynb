# %%
import pandas as pd
import csv

# %%
pl=pd.read_csv('plSP.csv',names=['time','date','id','homeTeam','awayTeam','1','X','2','1X','2X','12','O2.5','U2.5'])
pl
# Out:
#      time      date        id         homeTeam        awayTeam     1     X  \
# 0   22:45  12/01/22  ID: 3757         WEST HAM    NORWICH CITY  1.37  5.01
# 1   23:00  14/01/22  ID: 5827         BRIGHTON  CRYSTAL PALACE  2.08  3.22
# 2   15:30  15/01/22  ID: 4785  MANCHESTER CITY         CHELSEA  1.76  3.75
# 3   18:00  15/01/22  ID: 3858        NEWCASTLE         WATFORD  2.06  3.61
# 4   18:00  15/01/22  ID: 3391          BURNLEY       LEICESTER  2.88  3.38
# 5   18:00  15/01/22  ID: 4510     NORWICH CITY         EVERTON  3.71  3.46
# 6   18:00  15/01/22  ID: 1915    WOLVERHAMPTON     SOUTHAMPTON  2.20  3.21
# 7   20:30  15/01/22  ID: 4749      ASTON VILLA  MANCHESTER UTD  2.99  3.37
# 8   17:00  16/01/22  ID: 5490        LIVERPOOL       BRENTFORD  1.34  5.23
# 9   17:00  16/01/22  ID: 1391         WEST HAM           LEEDS  1.66  4.10
# 10  19:30  16/01/22  ID: 3355        TOTTENHAM         ARSENAL  2.48  3.31
# ...

# %%
pl2=pd.read_csv('plWIN.csv',index_col=[0])
pl2
# Out:
#                      HomeTeam                   AwayTeam     1     X      2  \
# 0            West Ham United                Norwich City  1.32  5.20   9.50
# 1   Brighton and Hove Albion              Crystal Palace  2.07  3.08   3.80
# 2            Manchester City                     Chelsea  1.65  3.94   4.75
# 3               Norwich City                     Everton  3.66  3.47   1.96
# 4                    Burnley              Leicester City  2.77  3.32   2.46
# 5    Wolverhampton Wanderers                 Southampton  2.22  3.05   3.45
# 6           Newcastle United                     Watford  2.00  3.45   3.57
# 7                Aston Villa           Manchester United  3.05  3.45   2.22
# 8                  Liverpool                   Brentford  1.28  5.30  10.00
# 9            West Ham United                Leeds United  1.59  4.10   5.10
# 10         Tottenham Hotspur                     Arsenal  2.52  3.20   2.76
# ...
